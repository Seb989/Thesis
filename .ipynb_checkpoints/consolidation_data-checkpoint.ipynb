# %% [markdown]
# # Libraries

# %%
import pandas as pd
import requests

pd.set_option('display.max_columns', None) # display all columns in DF

# %% [markdown]
# # Uploading data

# %%
df_orangebook = pd.read_excel('Searchable Database of Orange Book Drug Patents.xlsx', skiprows = 1)
df_openFDA = pd.read_excel('raw_openFDA_data.xlsx')  
df_medicaid = pd.read_csv('raw_medicaid_data.csv')

# %%
len(df_openFDA)
# Out:
# 25374

# %% [markdown]
# # Data manipulation

# %% [markdown]
# ### OpenFDA

# %%
df = df_openFDA
len(df)
# Out:
# 25374

# %%
df.dtypes
# Out:
# submissions                   object
# application_number            object
# sponsor_name                  object
# products                      object
# openfda.application_number    object
# openfda.brand_name            object
# openfda.generic_name          object
# openfda.manufacturer_name     object
# openfda.product_ndc           object
# openfda.product_type          object
# openfda.route                 object
# openfda.substance_name        object
# openfda.rxcui                 object
# openfda.spl_id                object
# openfda.spl_set_id            object
# openfda.package_ndc           object
# openfda.unii                  object
# openfda.nui                   object
# openfda.pharm_class_epc       object
# openfda.pharm_class_cs        object
# openfda.pharm_class_moa       object
# openfda.pharm_class_pe        object
# dtype: object

# %%
df = df.explode('openfda.product_ndc') # unpacking lists
len(df)
# Out:
# 25374

# %%
df.head()
# Out:
#                                          submissions application_number  \
# 0  [{'submission_type': 'SUPPL', 'submission_numb...         ANDA206552
# 1  [{'submission_type': 'SUPPL', 'submission_numb...          NDA019532
# 2  [{'submission_type': 'SUPPL', 'submission_numb...          NDA019594
# 3  [{'submission_type': 'SUPPL', 'submission_numb...          BLA125509
# 4  [{'submission_type': 'ORIG', 'submission_numbe...         ANDA200884
#
#               sponsor_name                                           products  \
# 0       FRESENIUS KABI USA  [{'product_number': '001', 'reference_drug': '...
# 1           LANNETT CO INC  [{'product_number': '001', 'reference_drug': '...
# 2                 ALLERGAN  [{'product_number': '001', 'reference_drug': '...
# 3  ELUSYS THERAPEUTICS INC  [{'product_number': '001', 'reference_drug': '...
# 4                SUN PHARM  [{'product_number': '002', 'reference_drug': '...
#
#   openfda.application_number  openfda.brand_name openfda.generic_name  \
# 0             ['ANDA206552']  ['HEPARIN SODIUM']   ['HEPARIN SODIUM']
# 1                        NaN                 NaN                  NaN
# 2              ['NDA019594']        ['URSODIOL']         ['URSODIOL']
# 3              ['BLA125509']          ['ANTHIM']    ['OBILTOXAXIMAB']
# 4             ['ANDA200884']     ['FENOFIBRATE']      ['FENOFIBRATE']
#
#                  openfda.manufacturer_name         openfda.product_ndc  \
# 0              ['Fresenius Kabi USA, LLC']               ['76045-108']
# 1                                      NaN                         NaN
# 2                 ['Actavis Pharma, Inc.']               ['0591-3159']
# 3            ['Elusys Therapeutics, Inc.']               ['69604-204']
# 4  ['Sun Pharmaceutical Industries, Inc.']  ['63304-448', '63304-449']
#
#           openfda.product_type                    openfda.route  \
# 0  ['HUMAN PRESCRIPTION DRUG']  ['INTRAVENOUS', 'SUBCUTANEOUS']
# 1                          NaN                              NaN
# 2  ['HUMAN PRESCRIPTION DRUG']                         ['ORAL']
# 3  ['HUMAN PRESCRIPTION DRUG']                  ['INTRAVENOUS']
# 4  ['HUMAN PRESCRIPTION DRUG']                         ['ORAL']
#
#   openfda.substance_name           openfda.rxcui  \
# 0     ['HEPARIN SODIUM']             ['1798389']
# 1                    NaN                     NaN
# 2           ['URSODIOL']              ['858747']
# 3      ['OBILTOXAXIMAB']  ['1746910', '1746915']
# 4        ['FENOFIBRATE']    ['477560', '477562']
#
#                              openfda.spl_id  \
# 0  ['151a54ec-f7e5-4e6d-9810-cbfa75a16a22']
# 1                                       NaN
# 2  ['9f386262-71fb-48f0-b992-773d35e952c5']
# 3  ['9a6bcd22-1783-400b-b87a-c825315f600c']
# 4  ['5f5e6f81-fe5a-4ad6-be4e-0cf5f28a0f00']
#
#                          openfda.spl_set_id  \
# 0  ['07438e10-1589-4683-9f26-e5494d076cf0']
# 1                                       NaN
# 2  ['a061bb07-a85d-4b08-877f-ce02156f0de7']
# 3  ['39ad8799-00a4-4fc8-9852-c0536350c474']
# 4  ['125bbd7e-86a2-4209-90a5-ad353e572d1b']
#
#                                  openfda.package_ndc    openfda.unii  \
# 0                   ['76045-108-00', '76045-108-10']  ['ZZ45AB24CA']
# 1                                                NaN             NaN
# 2                                   ['0591-3159-01']  ['724L30Y2QR']
# 3                                   ['69604-204-02']  ['29Z5DNL48C']
# 4  ['63304-448-30', '63304-448-90', '63304-448-05...  ['U202363UOS']
#
#                                   openfda.nui  \
# 0                                         NaN
# 1                                         NaN
# 2                 ['N0000175802', 'M0002475']
# 3              ['N0000192703', 'N0000192702']
# 4  ['N0000175596', 'N0000175375', 'M0199111']
#
#                              openfda.pharm_class_epc  \
# 0                                                NaN
# 1                                                NaN
# 2                                ['Bile Acid [EPC]']
# 3  ['Anthrax Protective Antigen-directed Antibody...
# 4  ['Peroxisome Proliferator Receptor alpha Agoni...
#
#           openfda.pharm_class_cs  \
# 0                            NaN
# 1                            NaN
# 2  ['Bile Acids and Salts [CS]']
# 3                            NaN
# 4            ['PPAR alpha [CS]']
#
#                              openfda.pharm_class_moa openfda.pharm_class_pe
# 0                                                NaN                    NaN
# 1                                                NaN                    NaN
# 2                                                NaN                    NaN
# 3  ['Anthrax Protective Antigen-directed Antibody...                    NaN
# 4  ['Peroxisome Proliferator-activated Receptor a...                    NaN

# %% [markdown]
# ### Medicaid

# %%
df_medicaid['labeler_code'] = pd.to_numeric(df_medicaid['labeler_code'])
df_medicaid['labeler_code'] = pd.to_numeric(df_medicaid['product_code'])

# %% [markdown]
# # Merging data

# %% [markdown]
# ### Orange Book and OpenFDA

# %% [markdown]
# Creating a commen key

# %%
df_openFDA['NDA #'] = df_openFDA['application_number'].str.replace(r'\D', '') # cleaning application_number
df_openFDA['NDA #'] = pd.to_numeric(df_openFDA['NDA #'])

# %% [markdown]
# Merging

# %%
df = pd.merge(df_openFDA, df_orangebook, on="NDA #", how="left")

# %% [markdown]
# ### Orange Book, OpenFDA and Medicaid

# %%
df.head(10)
# Out:
#                                          submissions application_number  \
# 0  [{'submission_type': 'SUPPL', 'submission_numb...         ANDA206552
# 1  [{'submission_type': 'SUPPL', 'submission_numb...          NDA019532
# 2  [{'submission_type': 'SUPPL', 'submission_numb...          NDA019594
# 3  [{'submission_type': 'SUPPL', 'submission_numb...          BLA125509
# 4  [{'submission_type': 'ORIG', 'submission_numbe...         ANDA200884
# 5  [{'submission_type': 'ORIG', 'submission_numbe...         ANDA201687
# 6  [{'submission_type': 'SUPPL', 'submission_numb...         ANDA202204
# 7  [{'submission_type': 'SUPPL', 'submission_numb...         ANDA202553
# 8  [{'submission_type': 'SUPPL', 'submission_numb...         ANDA202906
# 9  [{'submission_type': 'ORIG', 'submission_numbe...         ANDA203299
#
#               sponsor_name                                           products  \
# 0       FRESENIUS KABI USA  [{'product_number': '001', 'reference_drug': '...
# 1           LANNETT CO INC  [{'product_number': '001', 'reference_drug': '...
# 2                 ALLERGAN  [{'product_number': '001', 'reference_drug': '...
# 3  ELUSYS THERAPEUTICS INC  [{'product_number': '001', 'reference_drug': '...
# 4                SUN PHARM  [{'product_number': '002', 'reference_drug': '...
# 5            ANCHEN PHARMS  [{'product_number': '001', 'reference_drug': '...
# 6                    HIKMA  [{'product_number': '001', 'reference_drug': '...
# 7          ACCORD HLTHCARE  [{'product_number': '003', 'reference_drug': '...
# 8       DR REDDYS LABS LTD  [{'product_number': '001', 'reference_drug': '...
# 9                    AKORN  [{'product_number': '001', 'reference_drug': '...
#
#   openfda.application_number      openfda.brand_name    openfda.generic_name  \
# 0             ['ANDA206552']      ['HEPARIN SODIUM']      ['HEPARIN SODIUM']
# 1                        NaN                     NaN                     NaN
# 2              ['NDA019594']            ['URSODIOL']            ['URSODIOL']
# 3              ['BLA125509']              ['ANTHIM']       ['OBILTOXAXIMAB']
# 4             ['ANDA200884']         ['FENOFIBRATE']         ['FENOFIBRATE']
# 5             ['ANDA201687']           ['TRETINOIN']           ['TRETINOIN']
# 6                        NaN                     NaN                     NaN
# 7                        NaN                     NaN                     NaN
# 8             ['ANDA202906']  ['MONTELUKAST SODIUM']  ['MONTELUKAST SODIUM']
# 9             ['ANDA203299']         ['BIMATOPROST']         ['BIMATOPROST']
#
#                  openfda.manufacturer_name         openfda.product_ndc  \
# 0              ['Fresenius Kabi USA, LLC']               ['76045-108']
# 1                                      NaN                         NaN
# 2                 ['Actavis Pharma, Inc.']               ['0591-3159']
# 3            ['Elusys Therapeutics, Inc.']               ['69604-204']
# 4  ['Sun Pharmaceutical Industries, Inc.']  ['63304-448', '63304-449']
# 5             ['Par Pharmaceutical, Inc.']               ['10370-268']
# 6                                      NaN                         NaN
# 7                                      NaN                         NaN
# 8      ["Dr.Reddy's Laboratories Limited"]               ['55111-763']
# 9          ['Hi-Tech Pharmacal Co., Inc.']               ['50383-908']
#
#           openfda.product_type                    openfda.route  \
# 0  ['HUMAN PRESCRIPTION DRUG']  ['INTRAVENOUS', 'SUBCUTANEOUS']
# 1                          NaN                              NaN
# 2  ['HUMAN PRESCRIPTION DRUG']                         ['ORAL']
# 3  ['HUMAN PRESCRIPTION DRUG']                  ['INTRAVENOUS']
# 4  ['HUMAN PRESCRIPTION DRUG']                         ['ORAL']
# 5  ['HUMAN PRESCRIPTION DRUG']                         ['ORAL']
# 6                          NaN                              NaN
# 7                          NaN                              NaN
# 8  ['HUMAN PRESCRIPTION DRUG']                         ['ORAL']
# 9  ['HUMAN PRESCRIPTION DRUG']                   ['OPHTHALMIC']
#
#    openfda.substance_name           openfda.rxcui  \
# 0      ['HEPARIN SODIUM']             ['1798389']
# 1                     NaN                     NaN
# 2            ['URSODIOL']              ['858747']
# 3       ['OBILTOXAXIMAB']  ['1746910', '1746915']
# 4         ['FENOFIBRATE']    ['477560', '477562']
# 5           ['TRETINOIN']              ['199159']
# 6                     NaN                     NaN
# 7                     NaN                     NaN
# 8  ['MONTELUKAST SODIUM']              ['351246']
# 9         ['BIMATOPROST']              ['308739']
#
#                              openfda.spl_id  \
# 0  ['151a54ec-f7e5-4e6d-9810-cbfa75a16a22']
# 1                                       NaN
# 2  ['9f386262-71fb-48f0-b992-773d35e952c5']
# 3  ['9a6bcd22-1783-400b-b87a-c825315f600c']
# 4  ['5f5e6f81-fe5a-4ad6-be4e-0cf5f28a0f00']
# 5  ['a3f53b5e-8c97-4d1d-be93-f09c740cc803']
# 6                                       NaN
# 7                                       NaN
# 8  ['1d9ac31e-956b-897f-2d41-da76d70dd40c']
# 9  ['2726cb5a-56a3-4736-9020-b2ccc7caca83']
#
#                          openfda.spl_set_id  \
# 0  ['07438e10-1589-4683-9f26-e5494d076cf0']
# 1                                       NaN
# 2  ['a061bb07-a85d-4b08-877f-ce02156f0de7']
# 3  ['39ad8799-00a4-4fc8-9852-c0536350c474']
# 4  ['125bbd7e-86a2-4209-90a5-ad353e572d1b']
# 5  ['9c4ae9d9-c2a0-4995-a27a-e3f0f0284db9']
# 6                                       NaN
# 7                                       NaN
# 8  ['3d3df874-d710-7fa4-bb21-434977518337']
# 9  ['ce5c7f22-ade3-41ea-8dd8-3ec0399d3279']
#
#                                  openfda.package_ndc    openfda.unii  \
# 0                   ['76045-108-00', '76045-108-10']  ['ZZ45AB24CA']
# 1                                                NaN             NaN
# 2                                   ['0591-3159-01']  ['724L30Y2QR']
# 3                                   ['69604-204-02']  ['29Z5DNL48C']
# 4  ['63304-448-30', '63304-448-90', '63304-448-05...  ['U202363UOS']
# 5                                   ['10370-268-01']  ['5688UTC01R']
# 6                                                NaN             NaN
# 7                                                NaN             NaN
# 8                   ['55111-763-07', '55111-763-03']  ['U1O3J18SFL']
# 9   ['50383-908-02', '50383-908-05', '50383-908-07']  ['QXS94885MZ']
#
#                                   openfda.nui  \
# 0                                         NaN
# 1                                         NaN
# 2                 ['N0000175802', 'M0002475']
# 3              ['N0000192703', 'N0000192702']
# 4  ['N0000175596', 'N0000175375', 'M0199111']
# 5                 ['N0000175607', 'M0018962']
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                 ['N0000175454', 'M0017805']
#
#                              openfda.pharm_class_epc  \
# 0                                                NaN
# 1                                                NaN
# 2                                ['Bile Acid [EPC]']
# 3  ['Anthrax Protective Antigen-directed Antibody...
# 4  ['Peroxisome Proliferator Receptor alpha Agoni...
# 5                                 ['Retinoid [EPC]']
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                     ['Prostaglandin Analog [EPC]']
#
#           openfda.pharm_class_cs  \
# 0                            NaN
# 1                            NaN
# 2  ['Bile Acids and Salts [CS]']
# 3                            NaN
# 4            ['PPAR alpha [CS]']
# 5             ['Retinoids [CS]']
# 6                            NaN
# 7                            NaN
# 8                            NaN
# 9        ['Prostaglandins [CS]']
#
#                              openfda.pharm_class_moa openfda.pharm_class_pe  \
# 0                                                NaN                    NaN
# 1                                                NaN                    NaN
# 2                                                NaN                    NaN
# 3  ['Anthrax Protective Antigen-directed Antibody...                    NaN
# 4  ['Peroxisome Proliferator-activated Receptor a...                    NaN
# 5                                                NaN                    NaN
# 6                                                NaN                    NaN
# 7                                                NaN                    NaN
# 8                                                NaN                    NaN
# 9                                                NaN                    NaN
#
#     NDA # Ingredient(s) Company Product Name Approval Date  \
# 0  206552           NaN     NaN          NaN           NaN
# 1   19532           NaN     NaN          NaN           NaN
# 2   19594           NaN     NaN          NaN           NaN
# 3  125509           NaN     NaN          NaN           NaN
# 4  200884           NaN     NaN          NaN           NaN
# 5  201687           NaN     NaN          NaN           NaN
# 6  202204           NaN     NaN          NaN           NaN
# 7  202553           NaN     NaN          NaN           NaN
# 8  202906           NaN     NaN          NaN           NaN
# 9  203299           NaN     NaN          NaN           NaN
#
#   Earliest Protection DateEarliest Prot. Date  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
#
#   Latest Protection DateLatest Prot. Date  dsad  \
# 0                                     NaN   NaN
# 1                                     NaN   NaN
# 2                                     NaN   NaN
# 3                                     NaN   NaN
# 4                                     NaN   NaN
# 5                                     NaN   NaN
# 6                                     NaN   NaN
# 7                                     NaN   NaN
# 8                                     NaN   NaN
# 9                                     NaN   NaN
#
#    Months of Additional Protection TimeMonths Add. Prot. Time  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#    Total Number of ProtectionsNum. Prot.  Unique Patents  \
# 0                                    NaN             NaN
# 1                                    NaN             NaN
# 2                                    NaN             NaN
# 3                                    NaN             NaN
# 4                                    NaN             NaN
# 5                                    NaN             NaN
# 6                                    NaN             NaN
# 7                                    NaN             NaN
# 8                                    NaN             NaN
# 9                                    NaN             NaN
#
#    Number of Orphan Drug ExclusivitiesNum. ODE's  Extensions
# 0                                            NaN         NaN
# 1                                            NaN         NaN
# 2                                            NaN         NaN
# 3                                            NaN         NaN
# 4                                            NaN         NaN
# 5                                            NaN         NaN
# 6                                            NaN         NaN
# 7                                            NaN         NaN
# 8                                            NaN         NaN
# 9                                            NaN         NaN
