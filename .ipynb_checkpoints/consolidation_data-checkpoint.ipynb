# %% [markdown]
# # Libraries

# %%
import pandas as pd
import requests

from ast import literal_eval

pd.set_option('display.max_columns', None) # display all columns in DF

# %% [markdown]
# # Uploading data

# %%
df_orangebook = pd.read_excel('Searchable Database of Orange Book Drug Patents.xlsx', skiprows = 1)
df_openFDA = pd.read_csv('raw_openFDA_data.csv')  
df_medicaid = pd.read_csv('raw_medicaid_data.csv')

# %% [markdown]
# # Data manipulation

# %% [markdown]
# ### OpenFDA

# %%
df_openFDA = df_openFDA.dropna(subset=['openfda.product_ndc'])

# %% [markdown]
# Clearing nda

# %%
df_openFDA['NDA #'] = df_openFDA['application_number'].str.replace(r'\D', '')
df_openFDA['NDA #'] = pd.to_numeric(df_openFDA['NDA #'])

# %% [markdown]
# Unpacking list for ndc

# %%
df_openFDA['openfda.product_ndc'] = df_openFDA['openfda.product_ndc'].apply(literal_eval)
df_openFDA = df_openFDA.explode('openfda.product_ndc')

# %% [markdown]
# Splitting ndc into labeler and product code

# %%
df_temp = df_openFDA['openfda.product_ndc'].str.split("-", n = 1, expand = True)
df_openFDA['labeler_code']= df_temp[0]
df_openFDA['product_code']= new[1]

# %% [markdown]
# ### Medicaid

# %%
df_medicaid['labeler_code'] = pd.to_numeric(df_medicaid['labeler_code'])
df_medicaid['labeler_code'] = pd.to_numeric(df_medicaid['product_code'])

# %% [markdown]
# # Merging data

# %% [markdown]
# ### Orange Book and OpenFDA

# %% [markdown]
# Merging

# %%
df = pd.merge(df_openFDA, df_orangebook, on="NDA #", how="left")

# %% [markdown]
# ### Orange Book, OpenFDA and Medicaid

# %%
df.head(10)
# Out:
#                                          submissions application_number  \
# 0  [{'submission_type': 'SUPPL', 'submission_numb...         ANDA206552
# 1  [{'submission_type': 'SUPPL', 'submission_numb...          NDA019594
# 2  [{'submission_type': 'SUPPL', 'submission_numb...          BLA125509
# 3  [{'submission_type': 'ORIG', 'submission_numbe...         ANDA200884
# 4  [{'submission_type': 'ORIG', 'submission_numbe...         ANDA200884
# 5  [{'submission_type': 'ORIG', 'submission_numbe...         ANDA201687
# 6  [{'submission_type': 'SUPPL', 'submission_numb...         ANDA202906
# 7  [{'submission_type': 'ORIG', 'submission_numbe...         ANDA203299
# 8  [{'submission_type': 'SUPPL', 'submission_numb...          NDA204063
# 9  [{'submission_type': 'SUPPL', 'submission_numb...          NDA204063
#
#               sponsor_name                                           products  \
# 0       FRESENIUS KABI USA  [{'product_number': '001', 'reference_drug': '...
# 1                 ALLERGAN  [{'product_number': '001', 'reference_drug': '...
# 2  ELUSYS THERAPEUTICS INC  [{'product_number': '001', 'reference_drug': '...
# 3                SUN PHARM  [{'product_number': '002', 'reference_drug': '...
# 4                SUN PHARM  [{'product_number': '002', 'reference_drug': '...
# 5            ANCHEN PHARMS  [{'product_number': '001', 'reference_drug': '...
# 6       DR REDDYS LABS LTD  [{'product_number': '001', 'reference_drug': '...
# 7                    AKORN  [{'product_number': '001', 'reference_drug': '...
# 8               BIOGEN INC  [{'product_number': '001', 'reference_drug': '...
# 9               BIOGEN INC  [{'product_number': '001', 'reference_drug': '...
#
#   openfda.application_number                  openfda.brand_name  \
# 0             ['ANDA206552']                  ['HEPARIN SODIUM']
# 1              ['NDA019594']                        ['URSODIOL']
# 2              ['BLA125509']                          ['ANTHIM']
# 3             ['ANDA200884']                     ['FENOFIBRATE']
# 4             ['ANDA200884']                     ['FENOFIBRATE']
# 5             ['ANDA201687']                       ['TRETINOIN']
# 6             ['ANDA202906']              ['MONTELUKAST SODIUM']
# 7             ['ANDA203299']                     ['BIMATOPROST']
# 8              ['NDA204063']  ['TECFIDERA', 'DIMETHYL FUMARATE']
# 9              ['NDA204063']  ['TECFIDERA', 'DIMETHYL FUMARATE']
#
#      openfda.generic_name                          openfda.manufacturer_name  \
# 0      ['HEPARIN SODIUM']                        ['Fresenius Kabi USA, LLC']
# 1            ['URSODIOL']                           ['Actavis Pharma, Inc.']
# 2       ['OBILTOXAXIMAB']                      ['Elusys Therapeutics, Inc.']
# 3         ['FENOFIBRATE']            ['Sun Pharmaceutical Industries, Inc.']
# 4         ['FENOFIBRATE']            ['Sun Pharmaceutical Industries, Inc.']
# 5           ['TRETINOIN']                       ['Par Pharmaceutical, Inc.']
# 6  ['MONTELUKAST SODIUM']                ["Dr.Reddy's Laboratories Limited"]
# 7         ['BIMATOPROST']                    ['Hi-Tech Pharmacal Co., Inc.']
# 8   ['DIMETHYL FUMARATE']  ['Biogen Inc.', 'TEVA PHARMACEUTICALS USA, INC.']
# 9   ['DIMETHYL FUMARATE']  ['Biogen Inc.', 'TEVA PHARMACEUTICALS USA, INC.']
#
#   openfda.product_ndc         openfda.product_type  \
# 0           76045-108  ['HUMAN PRESCRIPTION DRUG']
# 1           0591-3159  ['HUMAN PRESCRIPTION DRUG']
# 2           69604-204  ['HUMAN PRESCRIPTION DRUG']
# 3           63304-448  ['HUMAN PRESCRIPTION DRUG']
# 4           63304-449  ['HUMAN PRESCRIPTION DRUG']
# 5           10370-268  ['HUMAN PRESCRIPTION DRUG']
# 6           55111-763  ['HUMAN PRESCRIPTION DRUG']
# 7           50383-908  ['HUMAN PRESCRIPTION DRUG']
# 8           64406-005  ['HUMAN PRESCRIPTION DRUG']
# 9           64406-007  ['HUMAN PRESCRIPTION DRUG']
#
#                      openfda.route  openfda.substance_name  \
# 0  ['INTRAVENOUS', 'SUBCUTANEOUS']      ['HEPARIN SODIUM']
# 1                         ['ORAL']            ['URSODIOL']
# 2                  ['INTRAVENOUS']       ['OBILTOXAXIMAB']
# 3                         ['ORAL']         ['FENOFIBRATE']
# 4                         ['ORAL']         ['FENOFIBRATE']
# 5                         ['ORAL']           ['TRETINOIN']
# 6                         ['ORAL']  ['MONTELUKAST SODIUM']
# 7                   ['OPHTHALMIC']         ['BIMATOPROST']
# 8                         ['ORAL']   ['DIMETHYL FUMARATE']
# 9                         ['ORAL']   ['DIMETHYL FUMARATE']
#
#                                        openfda.rxcui  \
# 0                                        ['1798389']
# 1                                         ['858747']
# 2                             ['1746910', '1746915']
# 3                               ['477560', '477562']
# 4                               ['477560', '477562']
# 5                                         ['199159']
# 6                                         ['351246']
# 7                                         ['308739']
# 8  ['1373483', '1373489', '1373491', '1373493', '...
# 9  ['1373483', '1373489', '1373491', '1373493', '...
#
#                                       openfda.spl_id  \
# 0           ['151a54ec-f7e5-4e6d-9810-cbfa75a16a22']
# 1           ['9f386262-71fb-48f0-b992-773d35e952c5']
# 2           ['9a6bcd22-1783-400b-b87a-c825315f600c']
# 3           ['5f5e6f81-fe5a-4ad6-be4e-0cf5f28a0f00']
# 4           ['5f5e6f81-fe5a-4ad6-be4e-0cf5f28a0f00']
# 5           ['a3f53b5e-8c97-4d1d-be93-f09c740cc803']
# 6           ['1d9ac31e-956b-897f-2d41-da76d70dd40c']
# 7           ['2726cb5a-56a3-4736-9020-b2ccc7caca83']
# 8  ['c7c11174-dd00-47fa-8c12-3692da87756b', '0b26...
# 9  ['c7c11174-dd00-47fa-8c12-3692da87756b', '0b26...
#
#                                   openfda.spl_set_id  \
# 0           ['07438e10-1589-4683-9f26-e5494d076cf0']
# 1           ['a061bb07-a85d-4b08-877f-ce02156f0de7']
# 2           ['39ad8799-00a4-4fc8-9852-c0536350c474']
# 3           ['125bbd7e-86a2-4209-90a5-ad353e572d1b']
# 4           ['125bbd7e-86a2-4209-90a5-ad353e572d1b']
# 5           ['9c4ae9d9-c2a0-4995-a27a-e3f0f0284db9']
# 6           ['3d3df874-d710-7fa4-bb21-434977518337']
# 7           ['ce5c7f22-ade3-41ea-8dd8-3ec0399d3279']
# 8  ['665d7e74-036c-5f68-5b67-ab84b9b49151', '8e2c...
# 9  ['665d7e74-036c-5f68-5b67-ab84b9b49151', '8e2c...
#
#                                  openfda.package_ndc    openfda.unii  \
# 0                   ['76045-108-00', '76045-108-10']  ['ZZ45AB24CA']
# 1                                   ['0591-3159-01']  ['724L30Y2QR']
# 2                                   ['69604-204-02']  ['29Z5DNL48C']
# 3  ['63304-448-30', '63304-448-90', '63304-448-05...  ['U202363UOS']
# 4  ['63304-448-30', '63304-448-90', '63304-448-05...  ['U202363UOS']
# 5                                   ['10370-268-01']  ['5688UTC01R']
# 6                   ['55111-763-07', '55111-763-03']  ['U1O3J18SFL']
# 7   ['50383-908-02', '50383-908-05', '50383-908-07']  ['QXS94885MZ']
# 8  ['64406-007-03', '64406-005-01', '64406-006-02...  ['FO2303MNI2']
# 9  ['64406-007-03', '64406-005-01', '64406-006-02...  ['FO2303MNI2']
#
#                                   openfda.nui  \
# 0                                         NaN
# 1                 ['N0000175802', 'M0002475']
# 2              ['N0000192703', 'N0000192702']
# 3  ['N0000175596', 'N0000175375', 'M0199111']
# 4  ['N0000175596', 'N0000175375', 'M0199111']
# 5                 ['N0000175607', 'M0018962']
# 6                                         NaN
# 7                 ['N0000175454', 'M0017805']
# 8                                         NaN
# 9                                         NaN
#
#                              openfda.pharm_class_epc  \
# 0                                                NaN
# 1                                ['Bile Acid [EPC]']
# 2  ['Anthrax Protective Antigen-directed Antibody...
# 3  ['Peroxisome Proliferator Receptor alpha Agoni...
# 4  ['Peroxisome Proliferator Receptor alpha Agoni...
# 5                                 ['Retinoid [EPC]']
# 6                                                NaN
# 7                     ['Prostaglandin Analog [EPC]']
# 8                                                NaN
# 9                                                NaN
#
#           openfda.pharm_class_cs  \
# 0                            NaN
# 1  ['Bile Acids and Salts [CS]']
# 2                            NaN
# 3            ['PPAR alpha [CS]']
# 4            ['PPAR alpha [CS]']
# 5             ['Retinoids [CS]']
# 6                            NaN
# 7        ['Prostaglandins [CS]']
# 8                            NaN
# 9                            NaN
#
#                              openfda.pharm_class_moa openfda.pharm_class_pe  \
# 0                                                NaN                    NaN
# 1                                                NaN                    NaN
# 2  ['Anthrax Protective Antigen-directed Antibody...                    NaN
# 3  ['Peroxisome Proliferator-activated Receptor a...                    NaN
# 4  ['Peroxisome Proliferator-activated Receptor a...                    NaN
# 5                                                NaN                    NaN
# 6                                                NaN                    NaN
# 7                                                NaN                    NaN
# 8                                                NaN                    NaN
# 9                                                NaN                    NaN
#
#     NDA #      Ingredient(s)          Company Product Name Approval Date  \
# 0  206552                NaN              NaN          NaN           NaN
# 1   19594                NaN              NaN          NaN           NaN
# 2  125509                NaN              NaN          NaN           NaN
# 3  200884                NaN              NaN          NaN           NaN
# 4  200884                NaN              NaN          NaN           NaN
# 5  201687                NaN              NaN          NaN           NaN
# 6  202906                NaN              NaN          NaN           NaN
# 7  203299                NaN              NaN          NaN           NaN
# 8  204063  Dimethyl Fumarate  BIOGEN IDEC INC    Tecfidera     3/27/2013
# 9  204063  Dimethyl Fumarate  BIOGEN IDEC INC    Tecfidera     3/27/2013
#
#   Earliest Protection DateEarliest Prot. Date  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                    2/7/2018
# 9                                    2/7/2018
#
#   Latest Protection DateLatest Prot. Date    dsad  \
# 0                                     NaN     NaN
# 1                                     NaN     NaN
# 2                                     NaN     NaN
# 3                                     NaN     NaN
# 4                                     NaN     NaN
# 5                                     NaN     NaN
# 6                                     NaN     NaN
# 7                                     NaN     NaN
# 8                                2/7/2028  2028.0
# 9                                2/7/2028  2028.0
#
#    Months of Additional Protection TimeMonths Add. Prot. Time  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                              120.0
# 9                                              120.0
#
#    Total Number of ProtectionsNum. Prot.  Unique Patents  \
# 0                                    NaN             NaN
# 1                                    NaN             NaN
# 2                                    NaN             NaN
# 3                                    NaN             NaN
# 4                                    NaN             NaN
# 5                                    NaN             NaN
# 6                                    NaN             NaN
# 7                                    NaN             NaN
# 8                                   19.0             7.0
# 9                                   19.0             7.0
#
#    Number of Orphan Drug ExclusivitiesNum. ODE's  Extensions
# 0                                            NaN         NaN
# 1                                            NaN         NaN
# 2                                            NaN         NaN
# 3                                            NaN         NaN
# 4                                            NaN         NaN
# 5                                            NaN         NaN
# 6                                            NaN         NaN
# 7                                            NaN         NaN
# 8                                            0.0         2.0
# 9                                            0.0         2.0
